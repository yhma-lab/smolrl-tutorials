# %% [markdown]
# **一.Q learning‘s update formula**

# %% [markdown]
# **1. 计算 TD error**
#  $ r + \gamma \cdot \max_{a'} Q(s', a') - Q(s, a) $

# %%
def calc_q_update(
    self, state: ObsType, action: ActType, reward: Any, new_state: ObsType
):
    delta = (
        reward
        + self.gamma * self.qfunc.max_q_prime(new_state)
        - self.qfunc.get_q_value(state, action)
    )

# %% [markdown]
# **2. 计算 Q 值的更新**
#
# 基于 TD 残差 \( \delta \)，Q 值的更新公式为：
#
#
# $Q(s, a) \leftarrow Q(s, a) + \alpha \, \delta$

# %%
   q_update = self.qfunc.get_q_value(state, action) + self.learning_rate * delta
    return q_update

# %% [markdown]
# **3.更新Q表**

# %%
    def update(self, q_update, state, action):
        self.qfunc.update(q_update, state, action)

# %% [markdown]
# **二.Frozen Lake 的游戏画面和每个 episode 过程中 steps to goal 和 cumulated rewards 的变化曲线**

# %% [markdown]
# ![Figure_2.png](attachment:Figure_2.png)
# ![Figure_3.png](attachment:Figure_3.png)
# ![Figure_4.png](attachment:Figure_4.png)

# %% [markdown]
# **三.得到的统计分析和学习到的 Q Table 和每个状态下的 best action heatmap.**

# %% [markdown]
# ![2Figure_1.png](attachment:2Figure_1.png)
# ![2Figure_2.png](attachment:2Figure_2.png)

# %% [markdown]
# **四.改变proba_frozen后的结果**

# %% [markdown]
# ![3Figure_1.png](attachment:3Figure_1.png) ![3Figure_2.png](attachment:3Figure_2.png) ![3Figure_3.png](attachment:3Figure_3.png) ![3Figure_4.png](attachment:3Figure_4.png)
